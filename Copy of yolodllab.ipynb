# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rNujYixTlfjrmGOCzRMX")
project = rf.workspace("deep-kixzn").project("gasture")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.24, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to gasture-3 in yolov8:: 100%|██████████| 138/138 [00:00<00:00, 2077.46it/s]

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.11.8 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Setup complete ✅ (12 CPUs, 15.7 GB RAM, 237.2/474.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/IMG_20240410_133018.jpg' save = True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 326MB/s]
#
# 2024-04-10 10:33:19.591746: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-10 10:33:19.591798: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-10 10:33:19.704488: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-10 10:33:20.866675: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...

# %%
Image(filename='runs/detect/predict/IMG_20240410_133018.jpg', height=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e0ce4a5668ff> in <cell line: 1>()
# ----> 1 Image(filename='runs/detect/predict/IMG_20240410_133018.jpg', height=600)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
model = YOLO('/content/yolov8n.pt')
results = model.predict(source='/content/IMG_20240410_133018.jpg', conf=0.25)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= 'gasture-3\data.yaml' epochs=30 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.24 🚀 Python-3.11.8 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
Image(filename='/content/runs/detect/train3/confusion_matrix.png', width=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Image(filename='/content/runs/detect/train3/confusion_matrix.png', width=600)
#
# File c:\Users\Red\anaconda3\envs\torch_gpu\Lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File c:\Users\Red\anaconda3\envs\torch_gpu\Lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# ...

# %%
Image(filename='/content/runs/detect/train3/results.png', width=600)

# %%
Image(filename='/content/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %%
model = YOLO('/content/runs/detect/train3/weights/best.pt')
results = model.predict(source='/content/tu.png', conf=0.25)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
